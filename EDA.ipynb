# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from google.colab import files

# %%
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
! kaggle datasets download -d ruchi798/housing-prices-in-metropolitan-areas-of-india -p /content/sample_data/ --unzip
# Out:
#      <input type="file" id="files-f6c48045-dea4-41cb-90ad-3c0ad2acfd39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6c48045-dea4-41cb-90ad-3c0ad2acfd39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              233KB  2021-08-12 07:39:36          10590
# ...

# %%
df1 = pd.read_csv("/content/sample_data/Bangalore.csv")
df2 = pd.read_csv("/content/sample_data/Chennai.csv")
df3 = pd.read_csv("/content/sample_data/Delhi.csv")
df4 = pd.read_csv("/content/sample_data/Hyderabad.csv")
df5 = pd.read_csv("/content/sample_data/Kolkata.csv")
df6 = pd.read_csv("/content/sample_data/Mumbai.csv")

# %%
df1['City'] = 'Bangalore'
df2['City'] = 'Chennai'
df3['City'] = 'Delhi'
df4['City'] = 'Hyderabad'
df5['City'] = 'Kolkata'
df6['City'] = 'Mumbai'

df = pd.concat([df1, df2, df3, df4 ,df5 ,df6 ]).reset_index(drop=True)

# %%
df = df.rename(columns={"Children'splayarea":"KidsPlayArea"})

# %%
df['Price'] = df['Price']/100000

# %%
df.head()
# Out:
#     Price  Area  ... Refrigerator       City
# 0  300.00  3340  ...            0  Bangalore
# 1   78.88  1045  ...            0  Bangalore
# 2   48.66  1179  ...            0  Bangalore
# 3   83.58  1675  ...            0  Bangalore
# 4   68.45  1670  ...            0  Bangalore
#
# [5 rows x 41 columns]

# %% [markdown]
# Credit to Kaggle user sonukiller99 [1] for graphing

# %%
sns.set_style("whitegrid")
graph=sns.catplot(x='City', y='Price', data=df, jitter=0.3, height=6, aspect=2)
graph.fig.suptitle('House Prices in Cities');
graph.set_xlabels('City');
graph.set_ylabels('Price in 100,000');

# %% [markdown]
# Credit to Kaggle user sonukiller99 [1] for graphing

# %%
graph=sns.catplot(x='City', y='Area', data=df, jitter=0.4, height=6, aspect=2, )
graph.fig.suptitle('House Area in Cities');
graph.set_xlabels('City');
graph.set_ylabels('Area');

# %% [markdown]
# **Data obtain from DataMunging.ipynb**
#
# Total sample with missing Values; after removing missing location values
#
# *   Bangalore: 4256 of 6207: 1951: 1530
# *   Chennai: 2781 of 5014: 2233: 1917
# *   Delhi: 2996 of 4998: 2002: 1949
# *   Hyderabad: 84 of 2518: 2434: 2174
# *   Kolkata: 6507 of 6432: 75: 65
# *   Mumbai: 6321 of 7719: 1398: 1114
#
# Imputation:
# * Bangalore  shape: (4914, 41)
# * Chennai    shape: (4287, 41)
# * Delhi      shape: (4747, 41)
# * Hyderabad  shape: (2251, 41)
# * Kolkata    shape: (5553, 41)
# * Mumbai     shape: (6806, 41)

# %%
data = {'City':['Bangalore','Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai'],
        'All samples':[6207, 5014, 4998, 2518, 6432, 7719],
        'Samples with known locations':[4914, 4287, 4747, 2251, 5553, 6806],
        'Samples with no NaNs':[1951, 2233, 2002, 2434, 75, 1398],
        'Samples with known locations and no NaNs':[1530, 1917, 1949, 2174, 65, 1114],
        }

df1 = pd.DataFrame(data)

df1.plot(kind='bar', x='City', figsize = (15,8))
plt.xlabel('Cities')
plt.ylabel('Number of samples')
plt.show()

# %% [markdown]
# **Citations**
#
# [1]https://www.kaggle.com/sonukiller99/house-price-in-india/execution
